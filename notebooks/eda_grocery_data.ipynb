# %% [markdown]
# # Grocery Data EDA
# Exploratory Data Analysis of Blinkit-style synthetic grocery dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/grocery_data.csv')
df.head()
# Out:
#    product_id product_name product_category   price discount_level  \
# 0           1      Shampoo            Dairy   43.57            Low
# 1           2        Chips    Personal Care  260.26            Low
# 2           3       Tomato            Dairy  232.96           High
# 3           4         Soda       Vegetables  385.91         Medium
# 4           5      Shampoo       Vegetables  333.30         Medium
#
#    delivery_time  shelf_life_days  stock_quantity  customer_rating
# 0            119              280             158              4.5
# 1             15               11             144              4.4
# 2            106              351             107              1.8
# 3             80              134             122              2.9
# 4             56              303             182              3.5

# %%
# Product Category Distribution
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='product_category', order=df['product_category'].value_counts().index)
plt.title('Product Category Distribution')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/product_category_distribution.png')
plt.show()

# %%
# Average Price by Product Category
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='product_category', y='price', estimator='mean')
plt.title('Average Price by Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/avg_price_by_category.png')
plt.show()

# %%
# Delivery Time Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['delivery_time'], bins=30, kde=True)
plt.title('Delivery Time Distribution')
plt.tight_layout()
plt.savefig('../images/delivery_time_distribution.png')
plt.show()
